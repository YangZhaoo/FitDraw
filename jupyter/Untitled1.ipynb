# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

# %%
from parser import Record

# %%
from datetime import datetime
import time

# %%
param = {
    'timestamp': int(time.time()),
    'date_time': datetime.now(),
    'speed': 30,
    'location': None,
    'distance': 500
}

# %%
record = Record(**param)

# %%
record = Record(**init_param)

# %%
print(f'{record}')
# Out:
# record info:
# timestamp: 1763269407
# date time: 2025-11-16 13:03:27.442903+08:00
# speed: -- m/s
# location: --
# distance: Nonem
